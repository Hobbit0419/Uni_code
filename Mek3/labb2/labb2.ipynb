# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
rotation = np.array([770,710,670,630,590])
precession = np.array([0.111,0.119,0.126,0.135,0.143])

# Perform a linear fit
coefficients = np.polyfit(rotation, 1/precession, 1)
linear_fit = np.poly1d(coefficients)

k = coefficients[0]

fig1,ax1 = plt.subplots()
ax1.scatter(rotation,1/precession)
ax1.plot(rotation, linear_fit(rotation), color='red')

# %%
distance = np.array([64,32,0,-32,-64])
rotation = np.array([660,610,580,540,500])
precession = np.array([0.635,0.348,0,-0.374,-0.804])

fig2, ax2 = plt.subplots()
ax2.scatter(distance,precession)

# %%
mass = np.array([0,20,40,60,80,100])
rotation = np.array([780,720,660,610,570,520])
precession = np.array([0,0.0613,0.132,0.208,0.297,0.402])

fig3, ax3 = plt.subplots()
ax3.scatter(mass, precession)

# %%
rotation = np.array([740,680,640,600,540])
nutation = np.array([10.5,9.67,9.16,8.59,7.79])

coefficients = np.polyfit(rotation, nutation, 1)

print(coefficients)

fig4, ax4 = plt.subplots()
ax4.scatter(rotation, nutation)
ax4.plot(rotation, np.poly1d(np.polyfit(rotation, nutation, 1))(rotation), color='red')
# Out:
# [0.0135431  0.47441379]
